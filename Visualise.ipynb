# %% [markdown]
# # Visualize Test Workspace

# %% [markdown]
# ## Visualizing User types in different cities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1=pd.read_csv('chicago.csv')
df2=pd.read_csv('new_york_city.csv')
df3=pd.read_csv('washington.csv')

# %%
df1['City']='C'
df2['City']='N'
df3['City']='W'

# %%
frames = [df1,df2,df3]
df4=pd.concat(frames,sort=False)

# %%
df4.groupby(['City'])['User Type'].value_counts()
# Out:
# City  User Type
# C     Subscriber    238889
#       Customer       61110
#       Dependent          1
# N     Subscriber    269149
#       Customer       30159
# W     Subscriber    220786
#       Customer       79214
# Name: User Type, dtype: int64

# %%
df5=df4.groupby(['City'])['User Type'].value_counts()

# %%
df6=df5.unstack(level=1).reset_index().rename_axis(None, axis=1)

# %%
df6
# Out:
#   City  Customer  Dependent  Subscriber
# 0    C   61110.0        1.0    238889.0
# 1    N   30159.0        NaN    269149.0
# 2    W   79214.0        NaN    220786.0

# %%
df6x
# Out:
#   City  Customer  Dependent  Subscriber
# 0    C   61110.0        1.0    238889.0
# 1    N   30159.0        NaN    269149.0
# 2    W   79214.0        NaN    220786.0

# %%
df6.plot.bar(x='City',y=['Customer','Dependent','Subscriber'])

# %% [markdown]
# ## Visualizing users birthdate wise

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'Start Time', 'End Time', 'Trip Duration',
#        'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year',
#        'City'],
#       dtype='object')

# %%
df5=df4.groupby(['Birth Year'])['User Type'].value_counts()

# %%
df5
# Out:
# Birth Year  User Type
# 1885.0      Subscriber       13
# 1886.0      Subscriber        2
# 1888.0      Subscriber        1
# 1893.0      Subscriber        8
# 1895.0      Subscriber        2
# 1899.0      Subscriber       27
# 1900.0      Subscriber       46
# 1901.0      Subscriber       22
# 1906.0      Subscriber        7
# 1907.0      Subscriber        1
# 1909.0      Subscriber        2
# 1910.0      Subscriber        7
# 1912.0      Subscriber        7
# 1913.0      Subscriber        2
# 1916.0      Subscriber        5
# 1917.0      Subscriber        5
# 1918.0      Subscriber       47
# 1921.0      Subscriber       33
# 1923.0      Subscriber        6
# 1926.0      Subscriber       10
# 1927.0      Subscriber        3
# 1928.0      Subscriber        3
# 1930.0      Subscriber        4
# 1931.0      Subscriber        4
# 1932.0      Subscriber       16
# 1933.0      Subscriber        4
# 1934.0      Subscriber       57
# 1935.0      Subscriber        6
# 1936.0      Subscriber       16
# 1937.0      Subscriber       14
#                           ...
# 1988.0      Subscriber    23220
#             Customer        198
# 1989.0      Subscriber    25557
#             Customer        208
# 1990.0      Subscriber    22942
#             Customer        217
# 1991.0      Subscriber    21950
#             Customer        251
# 1992.0      Subscriber    19308
#             Customer        203
# 1993.0      Subscriber    15069
#             Customer        211
# 1994.0      Subscriber     8598
#             Customer        142
# 1995.0      Subscriber     4029
#             Customer        153
# 1996.0      Subscriber     3070
#             Customer         98
# 1997.0      Subscriber     2494
#             Customer         82
# 1998.0      Subscriber     1344
#             Customer        108
# 1999.0      Subscriber      764
#             Customer         35
# 2000.0      Subscriber      464
# 2001.0      Subscriber       55
# 2002.0      Subscriber        2
# 2003.0      Subscriber        2
# 2004.0      Subscriber        1
# 2016.0      Subscriber        6
# Name: User Type, Length: 153, dtype: int64

# %%
df6=df5.unstack(level=1).reset_index().rename_axis(None, axis=1)

# %%
df6
# Out:
#     Birth Year  Customer  Dependent  Subscriber
# 0       1885.0       NaN        NaN        13.0
# 1       1886.0       NaN        NaN         2.0
# 2       1888.0       NaN        NaN         1.0
# 3       1893.0       NaN        NaN         8.0
# 4       1895.0       NaN        NaN         2.0
# 5       1899.0       NaN        NaN        27.0
# 6       1900.0       NaN        NaN        46.0
# 7       1901.0       NaN        NaN        22.0
# 8       1906.0       NaN        NaN         7.0
# 9       1907.0       NaN        NaN         1.0
# 10      1909.0       NaN        NaN         2.0
# 11      1910.0       NaN        NaN         7.0
# 12      1912.0       NaN        NaN         7.0
# 13      1913.0       NaN        NaN         2.0
# 14      1916.0       NaN        NaN         5.0
# 15      1917.0       NaN        NaN         5.0
# 16      1918.0       NaN        NaN        47.0
# 17      1921.0       NaN        NaN        33.0
# 18      1923.0       NaN        NaN         6.0
# 19      1926.0       NaN        NaN        10.0
# 20      1927.0       NaN        NaN         3.0
# 21      1928.0       NaN        NaN         3.0
# 22      1930.0       NaN        NaN         4.0
# 23      1931.0       NaN        NaN         4.0
# 24      1932.0       NaN        NaN        16.0
# 25      1933.0       NaN        NaN         4.0
# 26      1934.0       NaN        NaN        57.0
# 27      1935.0       NaN        NaN         6.0
# 28      1936.0       NaN        NaN        16.0
# 29      1937.0       NaN        NaN        14.0
# ..         ...       ...        ...         ...
# 68      1976.0      84.0        NaN     10203.0
# 69      1977.0      82.0        NaN     10992.0
# 70      1978.0     147.0        NaN     11291.0
# 71      1979.0     101.0        1.0     12146.0
# 72      1980.0     115.0        NaN     14257.0
# 73      1981.0     101.0        NaN     15641.0
# 74      1982.0     110.0        NaN     17149.0
# 75      1983.0     138.0        NaN     18166.0
# 76      1984.0     153.0        NaN     20679.0
# 77      1985.0     192.0        NaN     21153.0
# 78      1986.0     188.0        NaN     22340.0
# 79      1987.0     269.0        NaN     22480.0
# 80      1988.0     198.0        NaN     23220.0
# 81      1989.0     208.0        NaN     25557.0
# 82      1990.0     217.0        NaN     22942.0
# 83      1991.0     251.0        NaN     21950.0
# 84      1992.0     203.0        NaN     19308.0
# 85      1993.0     211.0        NaN     15069.0
# 86      1994.0     142.0        NaN      8598.0
# 87      1995.0     153.0        NaN      4029.0
# 88      1996.0      98.0        NaN      3070.0
# 89      1997.0      82.0        NaN      2494.0
# 90      1998.0     108.0        NaN      1344.0
# 91      1999.0      35.0        NaN       764.0
# 92      2000.0       NaN        NaN       464.0
# 93      2001.0       NaN        NaN        55.0
# 94      2002.0       NaN        NaN         2.0
# 95      2003.0       NaN        NaN         2.0
# 96      2004.0       NaN        NaN         1.0
# 97      2016.0       NaN        NaN         6.0
#
# [98 rows x 4 columns]

# %%
df6['Birth Year'].min()
# Out:
# 1885.0

# %%
min_x=int(df6['Birth Year'].min())
max_x=int(df6['Birth Year'].max())
x_count=(max_x+1-min_x)//14
xticks_1=np.array(list(range(min_x,max_x,x_count)))

# %%
xticks_1
# Out:
# array([1885, 1894, 1903, 1912, 1921, 1930, 1939, 1948, 1957, 1966, 1975,
#        1984, 1993, 2002, 2011])

# %%
def setup(ax,x_min,x_max,y_min,y_max):
    ax.spines['right'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.yaxis.set_major_locator(ticker.NullLocator())
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.tick_params(which='major', width=1.00)
    ax.tick_params(which='major', length=14)
    ax.tick_params(which='minor', width=0.75)
    ax.tick_params(which='minor', length=2.5)
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    ax.patch.set_alpha(0.0)

# %%
plt.figure(figsize=(8, 6))
n = 8

# %%
import matplotlib.ticker as ticker

# %%
plt.xticks(xticks_1,rotation=45)
ax = plt.subplot(n, 1, 4)
setup(ax,1885,2016,1,5)

df6.plot(kind='bar', y=['Customer','Dependent','Subscriber'], ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-246-f5a574258b45> in <module>()
# ----> 1 plt.xticks(xticks_1,rotation=45)
#       2 ax = plt.subplot(n, 1, 4)
#       3 setup(ax,1885,2016,1,5)
#       4
#       5 df6.plot(kind='bar', y=['Customer','Dependent','Subscriber'], ax=ax)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in xticks(*args, **kwargs)
#    1714         labels = ax.get_xticklabels()
#    1715     elif len(args)==1:
# -> 1716         locs = ax.set_xticks(args[0])
#    1717         labels = ax.get_xticklabels()
#    1718     elif len(args)==2:
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in set_xticks(self, ticks, minor)
#    3234             Default is ``False``.
#    3235         """
# -> 3236         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3237         self.stale = True
#    3238         return ret
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in set_ticks(self, ticks, minor)
#    1676         """
#    1677         # XXX if the user changes units, the information will be lost here
# -> 1678         ticks = self.convert_units(ticks)
#    1679         if len(ticks) > 1:
#    1680             xleft, xright = self.get_view_interval()
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1524             return x
#    1525
# -> 1526         ret = self.converter.convert(x, self.units, self)
#    1527         return ret
#    1528
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      63
#      64         # force an update so it also does type checking
# ---> 65         unit.update(values)
#      66
#      67         str2idx = np.vectorize(unit._mapping.__getitem__,
#
# AttributeError: 'NoneType' object has no attribute 'update'

# %%
xticks_1=['1','4']

# %% [markdown]
# ### Plot logic for above not complete yet....!!!

# %% [markdown]
# ## Visualize user station wise
# Permitted visulalizations:
#     1. Min vs Max
#     2. Avg vs min
#     3. Avg vs max

# %% [markdown]
# # TODO: above

# %% [markdown]
# ## Visualization : Time entries

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'Start Time', 'End Time', 'Trip Duration',
#        'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year',
#        'City'],
#       dtype='object')

# %%
df4['Start Time'] = pd.to_datetime(df4['Start Time'])

# %%
df4['month'] = df4['Start Time'].dt.month
df4['day_of_week'] = df4['Start Time'].dt.dayofweek

# %%
df4['hour'] = df4['Start Time'].dt.hour

# %%
df5=df4.groupby('day_of_week')['User Type'].value_counts()

# %%
df5
# Out:
# day_of_week  User Type
# 0            Subscriber    106780
#              Customer       19859
# 1            Subscriber    118389
#              Customer       15751
# 2            Subscriber    127169
#              Customer       15537
# 3            Subscriber    118199
#              Customer       16230
# 4            Subscriber    111090
#              Customer       20686
# 5            Subscriber     73469
#              Customer       41798
#              Dependent          1
# 6            Subscriber     73728
#              Customer       40622
# Name: User Type, dtype: int64

# %%
df6=df5.unstack(level=1).reset_index().rename_axis(None, axis=1)

# %%
df6
# Out:
#    day_of_week  Customer  Dependent  Subscriber
# 0            0   19859.0        NaN    106780.0
# 1            1   15751.0        NaN    118389.0
# 2            2   15537.0        NaN    127169.0
# 3            3   16230.0        NaN    118199.0
# 4            4   20686.0        NaN    111090.0
# 5            5   41798.0        1.0     73469.0
# 6            6   40622.0        NaN     73728.0

# %%
days_helper_list = ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']
df6['day_of_week']=df6['day_of_week'].apply(lambda x : days_helper_list[x] )

# %%
df6
# Out:
#   day_of_week  Customer  Dependent  Subscriber
# 0         MON   19859.0        NaN    106780.0
# 1         TUE   15751.0        NaN    118389.0
# 2         WED   15537.0        NaN    127169.0
# 3         THU   16230.0        NaN    118199.0
# 4         FRI   20686.0        NaN    111090.0
# 5         SAT   41798.0        1.0     73469.0
# 6         SUN   40622.0        NaN     73728.0

# %%
df6.plot.line(x='day_of_week',y=['Customer','Dependent','Subscriber'])

# %%
df7=df6.copy()

# %%
df7
# Out:
#   day_of_week  Customer  Dependent  Subscriber
# 0         MON   19859.0        NaN    106780.0
# 1         TUE   15751.0        NaN    118389.0
# 2         WED   15537.0        NaN    127169.0
# 3         THU   16230.0        NaN    118199.0
# 4         FRI   20686.0        NaN    111090.0
# 5         SAT   41798.0        1.0     73469.0
# 6         SUN   40622.0        NaN     73728.0

# %%
df7['day_of_week']=df7['day_of_week'].apply(lambda x : days_helper_list[x])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-356-174860a83789> in <module>()
# ----> 1 df7['day_of_week']=df7['day_of_week'].apply(lambda x : days_helper_list[x])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-356-174860a83789> in <lambda>(x)
# ----> 1 df7['day_of_week']=df7['day_of_week'].apply(lambda x : days_helper_list[x])
#
# TypeError: list indices must be integers or slices, not str

# %%
df7
# Out:
#   day_of_week  Customer  Dependent  Subscriber
# 0         MON   19859.0        NaN    106780.0
# 1         TUE   15751.0        NaN    118389.0
# 2         WED   15537.0        NaN    127169.0
# 3         THU   16230.0        NaN    118199.0
# 4         FRI   20686.0        NaN    111090.0
# 5         SAT   41798.0        1.0     73469.0
# 6         SUN   40622.0        NaN     73728.0

# %%
df7.set_index('day_of_week',inplace=True)

# %%
df7['day_of_week']=df7['day_of_week'].apply(lambda x : days_helper_list.index(x))

# %%
df7
# Out:
#    day_of_week  Customer  Dependent  Subscriber
# 0            0   19859.0        NaN    106780.0
# 1            1   15751.0        NaN    118389.0
# 2            2   15537.0        NaN    127169.0
# 3            3   16230.0        NaN    118199.0
# 4            4   20686.0        NaN    111090.0
# 5            5   41798.0        1.0     73469.0
# 6            6   40622.0        NaN     73728.0

# %%
df7.plot.bar()

# %%
ax=plt.subplot()
ax.bar(df7['day_of_week'].values-0.2,df7['Customer'].values, align='center',color='red',width=0.2,tick_label=days_helper_list)
ax.bar(df7['day_of_week'].values,df7['Subscriber'].values, align='center',color='blue',width=0.2,tick_label=days_helper_list)

plt.show()

# %%
df = pd.DataFrame({
    "name": ["Joe", "Sally", "Ananya"],
    "score": np.random.randint(0,100,size=3)
})
df
# Out:
#      name  score
# 0     Joe     27
# 1   Sally     14
# 2  Ananya      3

# %%
df.plot.bar()
plt.show()

# %%
df.set_index("name",inplace=True)
df
# Out:
#         score
# name
# Joe        27
# Sally      14
# Ananya      3

# %%
df.plot.bar()
plt.show()

# %%
import plotly.plotly as py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-376-de64b2c85dc6> in <module>()
# ----> 1 import plotly.plotly as py
#
# ModuleNotFoundError: No module named 'plotly'

# %%
df5=df4.groupby(['day_of_week', 'day_of_week_num'])['User Type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-377-adf672d6a803> in <module>()
# ----> 1 df5=df4.groupby(['day_of_week', 'day_of_week_num'])['User Type'].value_counts()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'day_of_week_num'

# %%
df4['day_of_week_num']=df4['day_of_week'].apply(lambda x: days_helper_list.index(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-379-372e3d898f81> in <module>()
# ----> 1 df4['day_of_week_num']=df4['day_of_week'].apply(lambda x: days_helper_list.index(x))
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-379-372e3d898f81> in <lambda>(x)
# ----> 1 df4['day_of_week_num']=df4['day_of_week'].apply(lambda x: days_helper_list.index(x))
#
# ValueError: 4 is not in list

# %%
df4.head()
# Out:
#    Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0     1423854 2017-06-23 15:09:32  2017-06-23 15:14:53          321.0
# 1      955915 2017-05-25 18:19:03  2017-05-25 18:45:53         1610.0
# 2        9031 2017-01-04 08:27:49  2017-01-04 08:34:45          416.0
# 3      304487 2017-03-06 13:49:38  2017-03-06 13:55:28          350.0
# 4       45207 2017-01-17 14:53:07  2017-01-17 15:02:01          534.0
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year City  month  day_of_week  hour
# 0    Male      1992.0    C      6            4    15
# 1  Female      1992.0    C      5            3    18
# 2    Male      1981.0    C      1            2     8
# 3    Male      1986.0    C      3            0    13
# 4    Male      1975.0    C      1            1    14

# %%
df4.rename(columns={'day_of_week':'day_of_week_num'},inplace=True)

# %%
df4.head()
# Out:
#    Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0     1423854 2017-06-23 15:09:32  2017-06-23 15:14:53          321.0
# 1      955915 2017-05-25 18:19:03  2017-05-25 18:45:53         1610.0
# 2        9031 2017-01-04 08:27:49  2017-01-04 08:34:45          416.0
# 3      304487 2017-03-06 13:49:38  2017-03-06 13:55:28          350.0
# 4       45207 2017-01-17 14:53:07  2017-01-17 15:02:01          534.0
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year City  month  day_of_week_num  hour
# 0    Male      1992.0    C      6                4    15
# 1  Female      1992.0    C      5                3    18
# 2    Male      1981.0    C      1                2     8
# 3    Male      1986.0    C      3                0    13
# 4    Male      1975.0    C      1                1    14

# %%
df4['day_of_week']=df4['day_of_week_num'].apply(lambda x: days_helper_list[x])

# %%
df4.head()
# Out:
#    Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0     1423854 2017-06-23 15:09:32  2017-06-23 15:14:53          321.0
# 1      955915 2017-05-25 18:19:03  2017-05-25 18:45:53         1610.0
# 2        9031 2017-01-04 08:27:49  2017-01-04 08:34:45          416.0
# 3      304487 2017-03-06 13:49:38  2017-03-06 13:55:28          350.0
# 4       45207 2017-01-17 14:53:07  2017-01-17 15:02:01          534.0
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year City  month  day_of_week_num  hour day_of_week
# 0    Male      1992.0    C      6                4    15         FRI
# 1  Female      1992.0    C      5                3    18         THU
# 2    Male      1981.0    C      1                2     8         WED
# 3    Male      1986.0    C      3                0    13         MON
# 4    Male      1975.0    C      1                1    14         TUE

# %%
df5=df4.groupby(['day_of_week', 'day_of_week_num'])['User Type'].value_counts()

# %%
df5=df5.unstack(level=2).reset_index().rename_axis(None, axis=1)

# %%
df5
# Out:
#   day_of_week  day_of_week_num  Customer  Dependent  Subscriber
# 0         FRI                4   20686.0        NaN    111090.0
# 1         MON                0   19859.0        NaN    106780.0
# 2         SAT                5   41798.0        1.0     73469.0
# 3         SUN                6   40622.0        NaN     73728.0
# 4         THU                3   16230.0        NaN    118199.0
# 5         TUE                1   15751.0        NaN    118389.0
# 6         WED                2   15537.0        NaN    127169.0

# %%
df5.sort_values('day_of_week_num',inplace=True)

# %%
df5
# Out:
#   day_of_week  day_of_week_num  Customer  Dependent  Subscriber
# 1         MON                0   19859.0        NaN    106780.0
# 5         TUE                1   15751.0        NaN    118389.0
# 6         WED                2   15537.0        NaN    127169.0
# 4         THU                3   16230.0        NaN    118199.0
# 0         FRI                4   20686.0        NaN    111090.0
# 2         SAT                5   41798.0        1.0     73469.0
# 3         SUN                6   40622.0        NaN     73728.0

# %%
df4
# Out:
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:32  2017-06-23 15:14:53        321.000
# 1           955915 2017-05-25 18:19:03  2017-05-25 18:45:53       1610.000
# 2             9031 2017-01-04 08:27:49  2017-01-04 08:34:45        416.000
# 3           304487 2017-03-06 13:49:38  2017-03-06 13:55:28        350.000
# 4            45207 2017-01-17 14:53:07  2017-01-17 15:02:01        534.000
# 5          1473887 2017-06-26 09:01:20  2017-06-26 09:11:06        586.000
# 6           961916 2017-05-26 09:41:44  2017-05-26 09:46:25        281.000
# 7            65924 2017-01-21 14:28:38  2017-01-21 14:40:41        723.000
# 8           606841 2017-04-20 16:08:51  2017-04-20 16:20:20        689.000
# 9           135470 2017-02-06 18:00:47  2017-02-06 18:09:00        493.000
# 10          175805 2017-02-15 07:09:55  2017-02-15 07:14:56        301.000
# 11           71678 2017-01-22 15:15:45  2017-01-22 15:31:02        917.000
# 12           19061 2017-01-08 16:03:00  2017-01-08 16:07:37        277.000
# 13         1023296 2017-05-30 15:46:18  2017-05-30 15:52:12        354.000
# 14          611000 2017-04-20 19:26:33  2017-04-20 19:35:08        515.000
# 15          958716 2017-05-25 22:59:33  2017-05-25 23:07:19        466.000
# 16          718598 2017-05-03 13:20:38  2017-05-03 13:31:13        635.000
# 17          931608 2017-05-23 08:08:25  2017-05-23 08:11:09        164.000
# 18         1469705 2017-06-25 21:26:30  2017-06-25 21:33:44        434.000
# 19          475456 2017-04-08 11:37:55  2017-04-08 11:51:55        840.000
# 20          849468 2017-05-16 06:36:17  2017-05-16 06:59:34       1397.000
# 21         1420915 2017-06-23 12:21:01  2017-06-23 12:32:54        713.000
# 22          161454 2017-02-12 15:24:29  2017-02-12 15:38:43        854.000
# 23         1413814 2017-06-22 19:14:37  2017-06-22 19:29:54        917.000
# 24          717248 2017-05-03 09:41:11  2017-05-03 09:49:10        479.000
# 25         1451810 2017-06-24 20:47:40  2017-06-24 21:13:39       1559.000
# 26          385517 2017-03-23 09:38:27  2017-03-23 09:42:41        254.000
# 27         1186035 2017-06-09 07:48:55  2017-06-09 07:52:30        215.000
# 28          512692 2017-04-11 18:49:57  2017-04-11 18:59:36        579.000
# 29          261757 2017-02-25 19:01:19  2017-02-25 19:08:10        411.000
# ...            ...                 ...                  ...            ...
# 299970     1471550 2017-06-09 11:43:16  2017-06-09 11:58:37        920.918
# 299971      177387 2017-02-01 09:40:00  2017-02-01 09:50:00        592.126
# 299972     1467942 2017-06-09 08:30:21  2017-06-09 08:36:00        338.889
# 299973     1647779 2017-06-23 08:56:52  2017-06-23 09:07:28        636.448
# 299974     1268465 2017-05-24 06:40:53  2017-05-24 06:49:44        531.641
# 299975      529787 2017-03-20 07:44:00  2017-03-20 07:50:00        376.236
# 299976     1387742 2017-06-03 07:36:32  2017-06-03 09:59:27       8574.520
# 299977      381662 2017-02-26 14:02:00  2017-02-26 14:14:00        695.843
# 299978     1497660 2017-06-11 11:36:59  2017-06-11 12:19:48       2569.064
# 299979       19230 2017-01-05 12:17:00  2017-01-05 12:35:00       1116.895
# 299980     1463439 2017-06-09 05:48:17  2017-06-09 05:55:36        438.578
# 299981       19978 2017-01-05 15:21:00  2017-01-05 15:45:00       1418.325
# 299982      285046 2017-02-16 17:42:00  2017-02-16 17:50:00        533.109
# 299983      197387 2017-02-04 07:29:00  2017-02-04 07:40:00        656.070
# 299984      306826 2017-02-19 11:21:00  2017-02-19 18:36:00      26104.597
# 299985     1272681 2017-05-24 09:16:44  2017-05-24 09:34:24       1060.293
# 299986      806988 2017-04-13 11:54:34  2017-04-13 12:18:57       1462.967
# 299987      477958 2017-03-10 12:30:00  2017-03-10 12:53:00       1365.523
# 299988     1207507 2017-05-19 04:16:14  2017-05-19 04:23:06        411.963
# 299989      102918 2017-01-20 17:43:00  2017-01-20 17:48:00        284.685
# 299990      776923 2017-04-11 11:11:57  2017-04-11 11:40:55       1738.345
# 299991        8834 2017-01-03 19:28:00  2017-01-03 19:40:00        714.928
# 299992       32912 2017-01-09 08:11:00  2017-01-09 08:14:00        191.131
# 299993      894445 2017-04-20 05:50:30  2017-04-20 06:10:35       1205.379
# 299994      101489 2017-01-20 14:03:00  2017-01-20 15:11:00       4086.828
# 299995      945535 2017-04-26 03:12:14  2017-04-26 03:41:19       1745.528
# 299996     1495781 2017-06-11 09:48:52  2017-06-11 10:22:31       2018.450
# 299997       12860 2017-01-04 14:33:00  2017-01-04 14:43:00        583.897
# 299998      977621 2017-04-28 07:17:47  2017-04-28 07:56:31       2324.170
# 299999     1553359 2017-06-16 04:08:16  2017-06-16 04:29:38       1281.459
#
#                                             Start Station  \
# 0                                    Wood St & Hubbard St
# 1                                     Theater on the Lake
# 2                                      May St & Taylor St
# 3                           Christiana Ave & Lawrence Ave
# 4                                  Clark St & Randolph St
# 5                            Clinton St & Washington Blvd
# 6                                   Ashland Ave & Lake St
# 7                              Larrabee St & Kingsbury St
# 8                                  Sedgwick St & Huron St
# 9                            Stetson Ave & South Water St
# 10                                   Broadway & Barry Ave
# 11                         Southport Ave & Wellington Ave
# 12                                  Green St & Madison St
# 13                             Larrabee St & Kingsbury St
# 14                                  Canal St & Madison St
# 15                                Clark St & Armitage Ave
# 16                               Ada St & Washington Blvd
# 17                                Damen Ave & Cortland St
# 18                                  State St & Pearson St
# 19                                      Adler Planetarium
# 20                                  Michigan Ave & Oak St
# 21                                     Rush St & Cedar St
# 22                             Clarendon Ave & Leland Ave
# 23                              Bissell St & Armitage Ave
# 24                              Wabash Ave & Roosevelt Rd
# 25                                     Rush St & Cedar St
# 26                               Loomis St & Jackson Blvd
# 27                                  Canal St & Madison St
# 28                                   Clinton St & Lake St
# 29                               Halsted St & Dickens Ave
# ...                                                   ...
# 299970                      17th St & Independence Ave SW
# 299971                                     12th & U St NW
# 299972                          Neal St & Trinidad Ave NE
# 299973                                      8th & O St NW
# 299974                                      5th & F St NW
# 299975                                         Lee Center
# 299976                                      5th & F St NW
# 299977         Aurora Hills Community Ctr/18th & Hayes St
# 299978                                     18th & C St NW
# 299979                                King St Metro South
# 299980  Eastern Market Metro / Pennsylvania Ave & 7th ...
# 299981                            Kennebec St & 11th St N
# 299982                        Adams Mill & Columbia Rd NW
# 299983                                     1st & N St  SE
# 299984                      22nd & I St NW / Foggy Bottom
# 299985                                     21st & M St NW
# 299986                  USDA / 12th & Independence Ave SW
# 299987                                 Jefferson Memorial
# 299988          Lincoln Park / 13th & East Capitol St NE
# 299989                                     14th & V St NW
# 299990                                      1st & O St NW
# 299991               Washington & Independence Ave SW/HHS
# 299992                                      Thomas Circle
# 299993                                      8th & H St NW
# 299994        Henry Bacon Dr & Lincoln Memorial Circle NW
# 299995                                   Lincoln Memorial
# 299996                              Key Blvd & N Quinn St
# 299997                   17th & K St NW / Farragut Square
# 299998                          Jefferson Dr & 14th St SW
# 299999                                10th & Monroe St NE
#
#                                               End Station   User Type  Gender  \
# 0                                 Damen Ave & Chicago Ave  Subscriber    Male
# 1                            Sheffield Ave & Waveland Ave  Subscriber  Female
# 2                                     Wood St & Taylor St  Subscriber    Male
# 3                            St. Louis Ave & Balmoral Ave  Subscriber    Male
# 4                            Desplaines St & Jackson Blvd  Subscriber    Male
# 5                                    Canal St & Taylor St  Subscriber    Male
# 6                                    Wood St & Hubbard St  Subscriber  Female
# 7                              Larrabee St & Armitage Ave    Customer     NaN
# 8                           Halsted St & Blackhawk St (*)  Subscriber    Male
# 9                            Clinton St & Washington Blvd  Subscriber    Male
# 10                               Wilton Ave & Belmont Ave  Subscriber  Female
# 11                                 Clark St & Schiller St  Subscriber    Male
# 12                               Ada St & Washington Blvd  Subscriber    Male
# 13                                      Clark St & Elm St  Subscriber    Male
# 14                        Racine Ave (May St) & Fulton St  Subscriber    Male
# 15                         Sheffield Ave & Wrightwood Ave  Subscriber  Female
# 16                                     Daley Center Plaza  Subscriber    Male
# 17                           Marshfield Ave & Cortland St  Subscriber    Male
# 18                                 Clark St & Schiller St  Subscriber    Male
# 19                                         Burnham Harbor    Customer     NaN
# 20                            Halsted St & Wrightwood Ave  Subscriber  Female
# 21                                 Halsted St & Willow St  Subscriber    Male
# 22                            Lake Shore Dr & Belmont Ave  Subscriber    Male
# 23                   Orleans St & Chestnut St (NEXT Apts)  Subscriber  Female
# 24                              Halsted St & Roosevelt Rd  Subscriber    Male
# 25                                 Halsted St & Roscoe St  Subscriber    Male
# 26                               Peoria St & Jackson Blvd  Subscriber  Female
# 27                                 Clark St & Randolph St  Subscriber    Male
# 28                    Mies van der Rohe Way & Chestnut St  Subscriber    Male
# 29                            Halsted St & Wrightwood Ave  Subscriber    Male
# ...                                                   ...         ...     ...
# 299970                                   Lincoln Memorial    Customer     NaN
# 299971                         North Capitol St & F St NW  Subscriber     NaN
# 299972                                      6th & H St NE  Subscriber     NaN
# 299973                             Eckington Pl & Q St NE  Subscriber     NaN
# 299974                           New Jersey Ave & R St NW  Subscriber     NaN
# 299975                                King St Metro South  Subscriber     NaN
# 299976                      Metro Center / 12th & G St NW    Customer     NaN
# 299977                            Potomac Ave & 35th St S  Subscriber     NaN
# 299978                                   Lincoln Memorial    Customer     NaN
# 299979                               King St & Patrick St    Customer     NaN
# 299980                           M St & New Jersey Ave SE  Subscriber     NaN
# 299981              Court House Metro / 15th & N Uhle St   Subscriber     NaN
# 299982                                11th & Kenyon St NW  Subscriber     NaN
# 299983  Eastern Market Metro / Pennsylvania Ave & 7th ...  Subscriber     NaN
# 299984                                     20th & L St NW    Customer     NaN
# 299985                  Convention Center / 7th & M St NW  Subscriber     NaN
# 299986                           4th & East Capitol St NE    Customer     NaN
# 299987                          New York Ave & 15th St NW    Customer     NaN
# 299988  Eastern Market Metro / Pennsylvania Ave & 7th ...  Subscriber     NaN
# 299989                                     15th & P St NW  Subscriber     NaN
# 299990                                      8th & O St NW  Subscriber     NaN
# 299991                                      3rd & H St NE  Subscriber     NaN
# 299992                   17th & K St NW / Farragut Square  Subscriber     NaN
# 299993                                     13th & H St NE    Customer     NaN
# 299994                                     24th & N St NW    Customer     NaN
# 299995                          Jefferson Dr & 14th St SW    Customer     NaN
# 299996                                      5th & K St NW  Subscriber     NaN
# 299997                     7th & F St NW/Portrait Gallery  Subscriber     NaN
# 299998               Washington & Independence Ave SW/HHS    Customer     NaN
# 299999                                      3rd & H St NW    Customer     NaN
#
#         Birth Year City  month  day_of_week_num  hour day_of_week
# 0           1992.0    C      6                4    15         FRI
# 1           1992.0    C      5                3    18         THU
# 2           1981.0    C      1                2     8         WED
# 3           1986.0    C      3                0    13         MON
# 4           1975.0    C      1                1    14         TUE
# 5           1990.0    C      6                0     9         MON
# 6           1983.0    C      5                4     9         FRI
# 7              NaN    C      1                5    14         SAT
# 8           1984.0    C      4                3    16         THU
# 9           1979.0    C      2                0    18         MON
# 10          1993.0    C      2                2     7         WED
# 11          1964.0    C      1                6    15         SUN
# 12          1961.0    C      1                6    16         SUN
# 13          1985.0    C      5                1    15         TUE
# 14          1984.0    C      4                3    19         THU
# 15          1985.0    C      5                3    22         THU
# 16          1967.0    C      5                2    13         WED
# 17          1990.0    C      5                1     8         TUE
# 18          1987.0    C      6                6    21         SUN
# 19             NaN    C      4                5    11         SAT
# 20          1992.0    C      5                1     6         TUE
# 21          1985.0    C      6                4    12         FRI
# 22          1980.0    C      2                6    15         SUN
# 23          1989.0    C      6                3    19         THU
# 24          1992.0    C      5                2     9         WED
# 25          1968.0    C      6                5    20         SAT
# 26          1985.0    C      3                3     9         THU
# 27          1974.0    C      6                4     7         FRI
# 28          1989.0    C      4                1    18         TUE
# 29          1970.0    C      2                5    19         SAT
# ...            ...  ...    ...              ...   ...         ...
# 299970         NaN    W      6                4    11         FRI
# 299971         NaN    W      2                2     9         WED
# 299972         NaN    W      6                4     8         FRI
# 299973         NaN    W      6                4     8         FRI
# 299974         NaN    W      5                2     6         WED
# 299975         NaN    W      3                0     7         MON
# 299976         NaN    W      6                5     7         SAT
# 299977         NaN    W      2                6    14         SUN
# 299978         NaN    W      6                6    11         SUN
# 299979         NaN    W      1                3    12         THU
# 299980         NaN    W      6                4     5         FRI
# 299981         NaN    W      1                3    15         THU
# 299982         NaN    W      2                3    17         THU
# 299983         NaN    W      2                5     7         SAT
# 299984         NaN    W      2                6    11         SUN
# 299985         NaN    W      5                2     9         WED
# 299986         NaN    W      4                3    11         THU
# 299987         NaN    W      3                4    12         FRI
# 299988         NaN    W      5                4     4         FRI
# 299989         NaN    W      1                4    17         FRI
# 299990         NaN    W      4                1    11         TUE
# 299991         NaN    W      1                1    19         TUE
# 299992         NaN    W      1                0     8         MON
# 299993         NaN    W      4                3     5         THU
# 299994         NaN    W      1                4    14         FRI
# 299995         NaN    W      4                2     3         WED
# 299996         NaN    W      6                6     9         SUN
# 299997         NaN    W      1                2    14         WED
# 299998         NaN    W      4                4     7         FRI
# 299999         NaN    W      6                4     4         FRI
#
# [900000 rows x 14 columns]

# %%
df_temp=df4.copy()

# %%
df_temp=df_temp.groupby('month')['User Type'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-427-05a6117bf4b1> in <module>()
# ----> 1 df_temp=df_temp.groupby('month')['User Type'].mean()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1304         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1305         try:
# -> 1306             return self._cython_agg_general('mean', **kwargs)
#    1307         except GroupByError:
#    1308             raise
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1054
#    1055         if len(output) == 0:
# -> 1056             raise DataError('No numeric types to aggregate')
#    1057
#    1058         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
df_temp
# Out:
# month  User Type
# 1      Subscriber     77780
#        Customer        5807
# 2      Subscriber     91379
#        Customer       14036
#        Dependent          1
# 3      Subscriber     90902
#        Customer       12543
# 4      Subscriber    131093
#        Customer       41362
# 5      Subscriber    150857
#        Customer       41106
# 6      Subscriber    186813
#        Customer       55629
# Name: User Type, dtype: int64

# %%
df_temp = df_temp.unstack(level=1).reset_index().rename_axis(None, axis=1)

# %%
df_temp
# Out:
#    month  Customer  Dependent  Subscriber
# 0      1    5807.0        NaN     77780.0
# 1      2   14036.0        1.0     91379.0
# 2      3   12543.0        NaN     90902.0
# 3      4   41362.0        NaN    131093.0
# 4      5   41106.0        NaN    150857.0
# 5      6   55629.0        NaN    186813.0

# %%
df4['month'].value_counts()
# Out:
# 6    242442
# 5    191963
# 4    172455
# 2    105730
# 3    103666
# 1     83744
# Name: month, dtype: int64

# %%
ax = plt.subplot()
month_helper_list = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
plt.plot(df_temp['month'].values, df_temp['Customer'].values, color='blue', label='Customer')
plt.plot(df_temp['month'].values, df_temp['Dependent'].values, color='red', label='Dependent')
plt.plot(df_temp['month'].values, df_temp['Subscriber'].values, color='green', label='Subscriber')

plt.xticks(df_temp['month'].values, month_helper_list)
ax.legend()
ax.autoscale_view()
plt.show()

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'Start Time', 'End Time', 'Trip Duration',
#        'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year',
#        'City', 'month', 'day_of_week_num', 'hour', 'day_of_week'],
#       dtype='object')

# %%
df4['Start Time'].head()
# Out:
# 0   2017-06-23 15:09:32
# 1   2017-05-25 18:19:03
# 2   2017-01-04 08:27:49
# 3   2017-03-06 13:49:38
# 4   2017-01-17 14:53:07
# Name: Start Time, dtype: datetime64[ns]

# %%
df4['hour']=df4['Start Time'].dt.hour

# %%
df=df4.copy()

# %%
df_temp=df.groupby('hour')['User Type'].value_counts()

# %%
df_temp
# Out:
# hour  User Type
# 0     Subscriber     3951
#       Customer        785
# 1     Subscriber     8638
#       Customer       5571
# 2     Subscriber     7293
#       Customer       5615
# 3     Subscriber     7715
#       Customer       5392
# 4     Subscriber    10887
#       Customer       5283
# 5     Subscriber    21513
#       Customer       5650
# 6     Subscriber    33089
#       Customer       5150
# 7     Subscriber    55572
#       Customer       5427
#       Dependent         1
# 8     Subscriber    75317
#       Customer       6396
# 9     Subscriber    45375
#       Customer       7817
# 10    Subscriber    30652
#       Customer      10712
# 11    Subscriber    32354
#       Customer      13384
# 12    Subscriber    37111
#       Customer      14931
# 13    Subscriber    29728
#       Customer      10689
# 14    Subscriber    29735
#       Customer      11568
# 15    Subscriber    33766
#       Customer      11907
# 16    Subscriber    47534
#       Customer      11330
# 17    Subscriber    69058
#       Customer      10258
# 18    Subscriber    54690
#       Customer       7516
# 19    Subscriber    36104
#       Customer       5328
# 20    Subscriber    23590
#       Customer       3734
# 21    Subscriber    16474
#       Customer       2652
# 22    Subscriber    11577
#       Customer       2061
# 23    Subscriber     7101
#       Customer       1327
# Name: User Type, dtype: int64

# %%
df_temp = df_temp.unstack(level=1).reset_index().rename_axis(None, axis=1)

# %%
df_temp
# Out:
#     hour  Customer  Dependent  Subscriber
# 0      0     785.0        NaN      3951.0
# 1      1    5571.0        NaN      8638.0
# 2      2    5615.0        NaN      7293.0
# 3      3    5392.0        NaN      7715.0
# 4      4    5283.0        NaN     10887.0
# 5      5    5650.0        NaN     21513.0
# 6      6    5150.0        NaN     33089.0
# 7      7    5427.0        1.0     55572.0
# 8      8    6396.0        NaN     75317.0
# 9      9    7817.0        NaN     45375.0
# 10    10   10712.0        NaN     30652.0
# 11    11   13384.0        NaN     32354.0
# 12    12   14931.0        NaN     37111.0
# 13    13   10689.0        NaN     29728.0
# 14    14   11568.0        NaN     29735.0
# 15    15   11907.0        NaN     33766.0
# 16    16   11330.0        NaN     47534.0
# 17    17   10258.0        NaN     69058.0
# 18    18    7516.0        NaN     54690.0
# 19    19    5328.0        NaN     36104.0
# 20    20    3734.0        NaN     23590.0
# 21    21    2652.0        NaN     16474.0
# 22    22    2061.0        NaN     11577.0
# 23    23    1327.0        NaN      7101.0

# %%
df=df4.copy()

# %%
df['day_in_month']=df['Start Time'].dt.day

# %%
df['day_of_week_num']=0

# %%
df_temp=df.groupby(['day_in_month','month','day_of_week','day_of_week_num'])['User Type'].value_counts()

# %%
df_temp
# Out:
# day_in_month  month  day_of_week  day_of_week_num  User Type
# 1             1      6            0                Subscriber    1256
#                                                    Customer       505
#               2      2            0                Subscriber    3931
#                                                    Customer       121
#               3      2            0                Subscriber    4083
#                                                    Customer       189
#               4      5            0                Subscriber    2866
#                                                    Customer      1307
#               5      0            0                Subscriber    4889
#                                                    Customer       721
#               6      3            0                Subscriber    7038
#                                                    Customer      1350
# 2             1      0            0                Subscriber    1019
#                                                    Customer        81
#               2      3            0                Subscriber    3438
#                                                    Customer       127
#               3      3            0                Subscriber    3819
#                                                    Customer       198
#               4      6            0                Subscriber    3298
#                                                    Customer      1896
#               5      1            0                Subscriber    5564
#                                                    Customer       791
#               6      4            0                Subscriber    7066
#                                                    Customer      1859
# 3             1      1            0                Subscriber    2134
#                                                    Customer        65
#               2      4            0                Subscriber    3131
#                                                    Customer        95
#               3      4            0                Subscriber    3277
#                                                    Customer       195
#                                                                  ...
# 28            5      6            0                Customer      3459
#                                                    Subscriber    3167
#               6      2            0                Subscriber    7130
#                                                    Customer      1124
# 29            1      6            0                Subscriber    1948
#                                                    Customer       265
#               3      2            0                Subscriber    4465
#                                                    Customer       639
#               4      5            0                Subscriber    3330
#                                                    Customer      2035
#               5      0            0                Subscriber    3543
#                                                    Customer      3082
#               6      3            0                Subscriber    6731
#                                                    Customer      1147
# 30            1      0            0                Subscriber    3129
#                                                    Customer        64
#               3      3            0                Subscriber    3705
#                                                    Customer       416
#               4      6            0                Subscriber    2930
#                                                    Customer      1605
#               5      1            0                Subscriber    5813
#                                                    Customer      1020
#               6      4            0                Subscriber    6583
#                                                    Customer      1684
# 31            1      1            0                Subscriber    3320
#                                                    Customer       109
#               3      4            0                Subscriber    1781
#                                                    Customer       113
#               5      2            0                Subscriber    6561
#                                                    Customer      1179
# Name: User Type, Length: 363, dtype: int64

# %%
df_temp=df_temp.unstack(level=4).reset_index().rename_axis(None, axis=1)

# %%
df_temp
# Out:
#      day_in_month  month  day_of_week  day_of_week_num  Customer  Dependent  \
# 0               1      1            6                0     505.0        NaN
# 1               1      2            2                0     121.0        NaN
# 2               1      3            2                0     189.0        NaN
# 3               1      4            5                0    1307.0        NaN
# 4               1      5            0                0     721.0        NaN
# 5               1      6            3                0    1350.0        NaN
# 6               2      1            0                0      81.0        NaN
# 7               2      2            3                0     127.0        NaN
# 8               2      3            3                0     198.0        NaN
# 9               2      4            6                0    1896.0        NaN
# 10              2      5            1                0     791.0        NaN
# 11              2      6            4                0    1859.0        NaN
# 12              3      1            1                0      65.0        NaN
# 13              3      2            4                0      95.0        NaN
# 14              3      3            4                0     195.0        NaN
# 15              3      4            0                0     606.0        NaN
# 16              3      5            2                0     875.0        NaN
# 17              3      6            5                0    3454.0        NaN
# 18              4      1            2                0     185.0        NaN
# 19              4      2            5                0     233.0        NaN
# 20              4      3            5                0     322.0        NaN
# 21              4      4            1                0     600.0        NaN
# 22              4      5            3                0     736.0        NaN
# 23              4      6            6                0    2776.0        NaN
# 24              5      1            3                0     105.0        NaN
# 25              5      2            6                0     275.0        NaN
# 26              5      3            6                0     488.0        NaN
# 27              5      4            2                0     738.0        NaN
# 28              5      5            4                0     462.0        NaN
# 29              5      6            0                0    1174.0        NaN
# ..            ...    ...          ...              ...       ...        ...
# 151            26      2            6                0     537.0        NaN
# 152            26      3            6                0     604.0        NaN
# 153            26      4            2                0     671.0        NaN
# 154            26      5            4                0    1291.0        NaN
# 155            26      6            0                0    1636.0        NaN
# 156            27      1            4                0     118.0        NaN
# 157            27      2            0                0     281.0        NaN
# 158            27      3            0                0     603.0        NaN
# 159            27      4            3                0     764.0        NaN
# 160            27      5            5                0    3539.0        NaN
# 161            27      6            1                0    1456.0        NaN
# 162            28      1            5                0     314.0        NaN
# 163            28      2            1                0     301.0        NaN
# 164            28      3            1                0     376.0        NaN
# 165            28      4            4                0    1315.0        NaN
# 166            28      5            6                0    3459.0        NaN
# 167            28      6            2                0    1124.0        NaN
# 168            29      1            6                0     265.0        NaN
# 169            29      3            2                0     639.0        NaN
# 170            29      4            5                0    2035.0        NaN
# 171            29      5            0                0    3082.0        NaN
# 172            29      6            3                0    1147.0        NaN
# 173            30      1            0                0      64.0        NaN
# 174            30      3            3                0     416.0        NaN
# 175            30      4            6                0    1605.0        NaN
# 176            30      5            1                0    1020.0        NaN
# 177            30      6            4                0    1684.0        NaN
# 178            31      1            1                0     109.0        NaN
# 179            31      3            4                0     113.0        NaN
# 180            31      5            2                0    1179.0        NaN
#
#      Subscriber
# 0        1256.0
# 1        3931.0
# 2        4083.0
# 3        2866.0
# 4        4889.0
# 5        7038.0
# 6        1019.0
# 7        3438.0
# 8        3819.0
# 9        3298.0
# 10       5564.0
# 11       7066.0
# 12       2134.0
# 13       3131.0
# 14       3277.0
# 15       4053.0
# 16       5961.0
# 17       5255.0
# 18       3149.0
# 19       1824.0
# 20       1846.0
# 21       4327.0
# 22       5496.0
# 23       4420.0
# 24       2765.0
# 25       2039.0
# 26       2054.0
# 27       4048.0
# 28       3511.0
# 29       6306.0
# ..          ...
# 151      2302.0
# 152      2036.0
# 153      5343.0
# 154      5027.0
# 155      6840.0
# 156      3454.0
# 157      4101.0
# 158      3564.0
# 159      5307.0
# 160      3687.0
# 161      7554.0
# 162      1975.0
# 163      4044.0
# 164      3703.0
# 165      5770.0
# 166      3167.0
# 167      7130.0
# 168      1948.0
# 169      4465.0
# 170      3330.0
# 171      3543.0
# 172      6731.0
# 173      3129.0
# 174      3705.0
# 175      2930.0
# 176      5813.0
# 177      6583.0
# 178      3320.0
# 179      1781.0
# 180      6561.0
#
# [181 rows x 7 columns]

# %%
df_temp.head()
# Out:
#    day_in_month  month  day_of_week_num   User Type   0   1       2   3   4  \
# 0             1      1                0    Customer NaN NaN     NaN NaN NaN
# 1             1      1                0  Subscriber NaN NaN     NaN NaN NaN
# 2             1      2                0    Customer NaN NaN   121.0 NaN NaN
# 3             1      2                0  Subscriber NaN NaN  3931.0 NaN NaN
# 4             1      3                0    Customer NaN NaN   189.0 NaN NaN
#
#     5       6
# 0 NaN   505.0
# 1 NaN  1256.0
# 2 NaN     NaN
# 3 NaN     NaN
# 4 NaN     NaN

# %%
df_temp
# Out:
#      day_in_month  month  day_of_week  day_of_week_num  Customer  Dependent  \
# 0               1      1            6                0     505.0        NaN
# 1               1      2            2                0     121.0        NaN
# 2               1      3            2                0     189.0        NaN
# 3               1      4            5                0    1307.0        NaN
# 4               1      5            0                0     721.0        NaN
# 5               1      6            3                0    1350.0        NaN
# 6               2      1            0                0      81.0        NaN
# 7               2      2            3                0     127.0        NaN
# 8               2      3            3                0     198.0        NaN
# 9               2      4            6                0    1896.0        NaN
# 10              2      5            1                0     791.0        NaN
# 11              2      6            4                0    1859.0        NaN
# 12              3      1            1                0      65.0        NaN
# 13              3      2            4                0      95.0        NaN
# 14              3      3            4                0     195.0        NaN
# 15              3      4            0                0     606.0        NaN
# 16              3      5            2                0     875.0        NaN
# 17              3      6            5                0    3454.0        NaN
# 18              4      1            2                0     185.0        NaN
# 19              4      2            5                0     233.0        NaN
# 20              4      3            5                0     322.0        NaN
# 21              4      4            1                0     600.0        NaN
# 22              4      5            3                0     736.0        NaN
# 23              4      6            6                0    2776.0        NaN
# 24              5      1            3                0     105.0        NaN
# 25              5      2            6                0     275.0        NaN
# 26              5      3            6                0     488.0        NaN
# 27              5      4            2                0     738.0        NaN
# 28              5      5            4                0     462.0        NaN
# 29              5      6            0                0    1174.0        NaN
# ..            ...    ...          ...              ...       ...        ...
# 151            26      2            6                0     537.0        NaN
# 152            26      3            6                0     604.0        NaN
# 153            26      4            2                0     671.0        NaN
# 154            26      5            4                0    1291.0        NaN
# 155            26      6            0                0    1636.0        NaN
# 156            27      1            4                0     118.0        NaN
# 157            27      2            0                0     281.0        NaN
# 158            27      3            0                0     603.0        NaN
# 159            27      4            3                0     764.0        NaN
# 160            27      5            5                0    3539.0        NaN
# 161            27      6            1                0    1456.0        NaN
# 162            28      1            5                0     314.0        NaN
# 163            28      2            1                0     301.0        NaN
# 164            28      3            1                0     376.0        NaN
# 165            28      4            4                0    1315.0        NaN
# 166            28      5            6                0    3459.0        NaN
# 167            28      6            2                0    1124.0        NaN
# 168            29      1            6                0     265.0        NaN
# 169            29      3            2                0     639.0        NaN
# 170            29      4            5                0    2035.0        NaN
# 171            29      5            0                0    3082.0        NaN
# 172            29      6            3                0    1147.0        NaN
# 173            30      1            0                0      64.0        NaN
# 174            30      3            3                0     416.0        NaN
# 175            30      4            6                0    1605.0        NaN
# 176            30      5            1                0    1020.0        NaN
# 177            30      6            4                0    1684.0        NaN
# 178            31      1            1                0     109.0        NaN
# 179            31      3            4                0     113.0        NaN
# 180            31      5            2                0    1179.0        NaN
#
#      Subscriber
# 0        1256.0
# 1        3931.0
# 2        4083.0
# 3        2866.0
# 4        4889.0
# 5        7038.0
# 6        1019.0
# 7        3438.0
# 8        3819.0
# 9        3298.0
# 10       5564.0
# 11       7066.0
# 12       2134.0
# 13       3131.0
# 14       3277.0
# 15       4053.0
# 16       5961.0
# 17       5255.0
# 18       3149.0
# 19       1824.0
# 20       1846.0
# 21       4327.0
# 22       5496.0
# 23       4420.0
# 24       2765.0
# 25       2039.0
# 26       2054.0
# 27       4048.0
# 28       3511.0
# 29       6306.0
# ..          ...
# 151      2302.0
# 152      2036.0
# 153      5343.0
# 154      5027.0
# 155      6840.0
# 156      3454.0
# 157      4101.0
# 158      3564.0
# 159      5307.0
# 160      3687.0
# 161      7554.0
# 162      1975.0
# 163      4044.0
# 164      3703.0
# 165      5770.0
# 166      3167.0
# 167      7130.0
# 168      1948.0
# 169      4465.0
# 170      3330.0
# 171      3543.0
# 172      6731.0
# 173      3129.0
# 174      3705.0
# 175      2930.0
# 176      5813.0
# 177      6583.0
# 178      3320.0
# 179      1781.0
# 180      6561.0
#
# [181 rows x 7 columns]

# %%
df_temp=df_temp.groupby('day_of_week').mean()

# %%
df_temp
# Out:
#              day_in_month     month  day_of_week_num     Customer  Dependent  \
# day_of_week
# 0               15.500000  3.461538              0.0   763.807692        NaN
# 1               16.500000  3.461538              0.0   605.807692        NaN
# 2               15.230769  3.538462              0.0   597.576923        NaN
# 3               15.038462  3.576923              0.0   624.230769        NaN
# 4               16.038462  3.576923              0.0   795.615385        NaN
# 5               15.240000  3.520000              0.0  1671.920000        1.0
# 6               15.653846  3.423077              0.0  1562.384615        NaN
#
#               Subscriber
# day_of_week
# 0            4106.923077
# 1            4553.423077
# 2            4891.115385
# 3            4546.115385
# 4            4272.692308
# 5            2938.760000
# 6            2835.692308
